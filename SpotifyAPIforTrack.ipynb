# %%
# import pandas as pd 
# import spotipy 
# sp = spotipy.Spotify() 
# from spotipy.oauth2 import SpotifyClientCredentials 
# cid ="CLIENT ID" 
# secret = "CLIENT SECRET" 
# client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
# sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
# sp.trace=False 
# playlist = sp.user_playlist("SPOTIFY_USERNAME", "PLAYLIST ID") 
# songs = playlist["tracks"]["items"] 
# ids = [] 
# for i in range(len(songs)): 
#     ids.append(songs[i]["track"]["id"]) 
# features = sp.audio_features(ids) 
# df = pd.DataFrame(features)

# %%
import base64

# %%
import datetime

# %%
import requests

# %%
from urllib.parse import urlencode

# %%
client_id = "01bc58e4e76d429f8bed442781557932"
client_secret = "086f054613e54f27ae2dba2c5eb14202"

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_audio_features(self, _id):
        return self.get_resource(_id, resource_type='audio_features')
    
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist' ):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search({"track": "goin bad"}, search_type="track")
# Out:
# q=track%3Agoin+bad&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Agoin+bad&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#        'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#        'id': '20sxb77xiYeusSH8cVdatc',
#        'name': 'Meek Mill',
#        'type': 'artist',
#        'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6UYZEYjpN1DYRW0kqFy9ZE'},
#      'href': 'https://api.spotify.com/v1/albums/6UYZEYjpN1DYRW0kqFy9ZE',
#      'id': '6UYZEYjpN1DYRW0kqFy9ZE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd63c5962050729d260077d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd63c5962050729d260077d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd63c5962050729d260077d6',
#        'width': 64}],
#      'name': 'Championships',
#      'release_date': '2018-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:6UYZEYjpN1DYRW0kqFy9ZE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#       'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#       'id': '20sxb77xiYeusSH8cVdatc',
#       'name': 'Meek Mill',
#       'type': 'artist',
#       'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 180522,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21812710'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2IRZnDFmlqMuOrYOLnZZyc'},
#     'href': 'https://api.spotify.com/v1/tracks/2IRZnDFmlqMuOrYOLnZZyc',
#     'id': '2IRZnDFmlqMuOrYOLnZZyc',
#     'is_local': False,
#     'name': 'Going Bad (feat. Drake)',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/29e19c68dd853994221a90103db28427f1185e33?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2IRZnDFmlqMuOrYOLnZZyc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#        'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#        'id': '20sxb77xiYeusSH8cVdatc',
#        'name': 'Meek Mill',
#        'type': 'artist',
#        'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'}],
#      'available_markets': ['AE',
#       'BH',
#       'BY',
#       'CA',
#       'EG',
#       'IN',
#       'JO',
#       'LB',
#       'OM',
#       'QA',
#       'SA',
#       'TN',
#       'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0psMalUoERrqQWc2sfWIrv'},
#      'href': 'https://api.spotify.com/v1/albums/0psMalUoERrqQWc2sfWIrv',
#      'id': '0psMalUoERrqQWc2sfWIrv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735132ca4fc74bf9ef23ffe1a8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025132ca4fc74bf9ef23ffe1a8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515132ca4fc74bf9ef23ffe1a8',
#        'width': 64}],
#      'name': 'Championships',
#      'release_date': '2018-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:0psMalUoERrqQWc2sfWIrv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#       'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#       'id': '20sxb77xiYeusSH8cVdatc',
#       'name': 'Meek Mill',
#       'type': 'artist',
#       'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AE',
#      'BH',
#      'BY',
#      'CA',
#      'EG',
#      'IN',
#      'JO',
#      'LB',
#      'OM',
#      'QA',
#      'SA',
#      'TN',
#      'US'],
#     'disc_number': 1,
#     'duration_ms': 180522,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21812711'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/47Mf1u67oqXtWBAaUHUSi7'},
#     'href': 'https://api.spotify.com/v1/tracks/47Mf1u67oqXtWBAaUHUSi7',
#     'id': '47Mf1u67oqXtWBAaUHUSi7',
#     'is_local': False,
#     'name': 'Going Bad (feat. Drake)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d712c4487a51e030a1e383287d9ee603b880879e?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:47Mf1u67oqXtWBAaUHUSi7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#        'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#        'id': '4TMHGUX5WI7OOm53PqSDAT',
#        'name': 'Grateful Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ObxRAQTpVO1u7bT3VxrIN'},
#      'href': 'https://api.spotify.com/v1/albums/0ObxRAQTpVO1u7bT3VxrIN',
#      'id': '0ObxRAQTpVO1u7bT3VxrIN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e30444f01f4d1eaeb1c6d526',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e30444f01f4d1eaeb1c6d526',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e30444f01f4d1eaeb1c6d526',
#        'width': 64}],
#      'name': 'Grateful Dead (Skull & Roses) [Live]',
#      'release_date': '1971-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0ObxRAQTpVO1u7bT3VxrIN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#       'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#       'id': '4TMHGUX5WI7OOm53PqSDAT',
#       'name': 'Grateful Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 552693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10105613'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JZeVTm20lmT0wTui4oWh9'},
#     'href': 'https://api.spotify.com/v1/tracks/3JZeVTm20lmT0wTui4oWh9',
#     'id': '3JZeVTm20lmT0wTui4oWh9',
#     'is_local': False,
#     'name': "Not Fade Away / Goin' down the Road Feeling Bad - Live at Manhattan Center, New York, NY, April 5, 1971",
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/956683cca348df11c13196cc827092ce65100600?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3JZeVTm20lmT0wTui4oWh9'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#        'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#        'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#        'name': 'Boosie Badazz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EEdfr0tQIbdFe6UKwK93O'},
#      'href': 'https://api.spotify.com/v1/albums/7EEdfr0tQIbdFe6UKwK93O',
#      'id': '7EEdfr0tQIbdFe6UKwK93O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730e8b4fb21c8585f910dde6b1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020e8b4fb21c8585f910dde6b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510e8b4fb21c8585f910dde6b1',
#        'width': 64}],
#      'name': 'Bad Azz',
#      'release_date': '2006-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7EEdfr0tQIbdFe6UKwK93O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#       'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#       'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#       'name': 'Boosie Badazz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aIm51fHkokqlJn2vzNTH8'},
#       'href': 'https://api.spotify.com/v1/artists/6aIm51fHkokqlJn2vzNTH8',
#       'id': '6aIm51fHkokqlJn2vzNTH8',
#       'name': 'Webbie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aIm51fHkokqlJn2vzNTH8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 281226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USEA20520052'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SLg4pBuYjZlYnevsex80Y'},
#     'href': 'https://api.spotify.com/v1/tracks/2SLg4pBuYjZlYnevsex80Y',
#     'id': '2SLg4pBuYjZlYnevsex80Y',
#     'is_local': False,
#     'name': "Goin' Thru Some Thangs",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6fd912e72733fdc596aa93e7147048457e02a951?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:2SLg4pBuYjZlYnevsex80Y'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DvtabXAjfrMihPP6JQdHs'},
#        'href': 'https://api.spotify.com/v1/artists/1DvtabXAjfrMihPP6JQdHs',
#        'id': '1DvtabXAjfrMihPP6JQdHs',
#        'name': 'Shy Glizzy',
#        'type': 'artist',
#        'uri': 'spotify:artist:1DvtabXAjfrMihPP6JQdHs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UVjijUdOs9JG3iuqAxBOS'},
#      'href': 'https://api.spotify.com/v1/albums/2UVjijUdOs9JG3iuqAxBOS',
#      'id': '2UVjijUdOs9JG3iuqAxBOS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733374a429143ba29c5ddda240',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023374a429143ba29c5ddda240',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513374a429143ba29c5ddda240',
#        'width': 64}],
#      'name': 'FTO',
#      'release_date': '2015-10-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2UVjijUdOs9JG3iuqAxBOS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DvtabXAjfrMihPP6JQdHs'},
#       'href': 'https://api.spotify.com/v1/artists/1DvtabXAjfrMihPP6JQdHs',
#       'id': '1DvtabXAjfrMihPP6JQdHs',
#       'name': 'Shy Glizzy',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DvtabXAjfrMihPP6JQdHs'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#       'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#       'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#       'name': 'Boosie Badazz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 189741,
#     'explicit': True,
#     'external_ids': {'isrc': 'USLD90812670'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Ime7bLYqZ7pCWtTKp38Cv'},
#     'href': 'https://api.spotify.com/v1/tracks/3Ime7bLYqZ7pCWtTKp38Cv',
#     'id': '3Ime7bLYqZ7pCWtTKp38Cv',
#     'is_local': False,
#     'name': 'Going Thru Shit (feat. Boosie)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0be499962620d6cc3545e2236e34169345300276?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3Ime7bLYqZ7pCWtTKp38Cv'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sbiAes6kYSnNq5hLu38uf'},
#        'href': 'https://api.spotify.com/v1/artists/7sbiAes6kYSnNq5hLu38uf',
#        'id': '7sbiAes6kYSnNq5hLu38uf',
#        'name': 'Ombre2Choc Nation',
#        'type': 'artist',
#        'uri': 'spotify:artist:7sbiAes6kYSnNq5hLu38uf'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jJHwVubFhB3nZkERcMsXl'},
#      'href': 'https://api.spotify.com/v1/albums/1jJHwVubFhB3nZkERcMsXl',
#      'id': '1jJHwVubFhB3nZkERcMsXl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273811dfaf43ce0397c3615dda7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02811dfaf43ce0397c3615dda7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851811dfaf43ce0397c3615dda7',
#        'width': 64}],
#      'name': 'Barbie Goin Bad (Remix)',
#      'release_date': '2019-11-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1jJHwVubFhB3nZkERcMsXl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sbiAes6kYSnNq5hLu38uf'},
#       'href': 'https://api.spotify.com/v1/artists/7sbiAes6kYSnNq5hLu38uf',
#       'id': '7sbiAes6kYSnNq5hLu38uf',
#       'name': 'Ombre2Choc Nation',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sbiAes6kYSnNq5hLu38uf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 195007,
#     'explicit': True,
#     'external_ids': {'isrc': 'FRDCX1902300'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3wKbo2grLJsJHbVLGkPTC3'},
#     'href': 'https://api.spotify.com/v1/tracks/3wKbo2grLJsJHbVLGkPTC3',
#     'id': '3wKbo2grLJsJHbVLGkPTC3',
#     'is_local': False,
#     'name': 'Barbie Goin Bad (Remix)',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3fac8bcfe3cfa96ca63f6c630db67950d5e77636?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3wKbo2grLJsJHbVLGkPTC3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GekK1oMVU35jfChgIP2PU'},
#        'href': 'https://api.spotify.com/v1/artists/7GekK1oMVU35jfChgIP2PU',
#        'id': '7GekK1oMVU35jfChgIP2PU',
#        'name': 'Doc & Merle Watson',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GekK1oMVU35jfChgIP2PU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/21k6Gb6ldqVsUfWY9culSS'},
#      'href': 'https://api.spotify.com/v1/albums/21k6Gb6ldqVsUfWY9culSS',
#      'id': '21k6Gb6ldqVsUfWY9culSS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739504639b4636d4a1bd8c8a7d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029504639b4636d4a1bd8c8a7d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519504639b4636d4a1bd8c8a7d',
#        'width': 64}],
#      'name': 'Elementary Doctor Watson',
#      'release_date': '1972',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:21k6Gb6ldqVsUfWY9culSS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GekK1oMVU35jfChgIP2PU'},
#       'href': 'https://api.spotify.com/v1/artists/7GekK1oMVU35jfChgIP2PU',
#       'id': '7GekK1oMVU35jfChgIP2PU',
#       'name': 'Doc & Merle Watson',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GekK1oMVU35jfChgIP2PU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 166200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560568816'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1rJhtyKJFEEmVzIJdAp7qq'},
#     'href': 'https://api.spotify.com/v1/tracks/1rJhtyKJFEEmVzIJdAp7qq',
#     'id': '1rJhtyKJFEEmVzIJdAp7qq',
#     'is_local': False,
#     'name': 'Going Down The Road Feeling Bad',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34a6980e087798397335d17e5f2acd5b71ba287e?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1rJhtyKJFEEmVzIJdAp7qq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#        'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#        'id': '4TMHGUX5WI7OOm53PqSDAT',
#        'name': 'Grateful Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3EUx54No5UpMca8zIyTpbd'},
#      'href': 'https://api.spotify.com/v1/albums/3EUx54No5UpMca8zIyTpbd',
#      'id': '3EUx54No5UpMca8zIyTpbd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273017918eba257a43eabf0035f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02017918eba257a43eabf0035f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851017918eba257a43eabf0035f',
#        'width': 64}],
#      'name': "Pacific Northwest '73-'74: Believe It If You Need It (Live)",
#      'release_date': '2018-09-07',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3EUx54No5UpMca8zIyTpbd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#       'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#       'id': '4TMHGUX5WI7OOm53PqSDAT',
#       'name': 'Grateful Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 421053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH11801956'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34MFx4e30wwelAmN9GrUCS'},
#     'href': 'https://api.spotify.com/v1/tracks/34MFx4e30wwelAmN9GrUCS',
#     'id': '34MFx4e30wwelAmN9GrUCS',
#     'is_local': False,
#     'name': "Goin' down the Road Feeling Bad - Live at Portland Memorial Coliseum, Portland, OR 5/19/74",
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1518be39fb594100a28c7205be86b1ce6fcb1f61?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:34MFx4e30wwelAmN9GrUCS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HTnM2pBGio6w5JhaUmb4o'},
#        'href': 'https://api.spotify.com/v1/artists/5HTnM2pBGio6w5JhaUmb4o',
#        'id': '5HTnM2pBGio6w5JhaUmb4o',
#        'name': 'NAME SIX',
#        'type': 'artist',
#        'uri': 'spotify:artist:5HTnM2pBGio6w5JhaUmb4o'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6gxgpYoqW5GcOaF14BcLp5'},
#      'href': 'https://api.spotify.com/v1/albums/6gxgpYoqW5GcOaF14BcLp5',
#      'id': '6gxgpYoqW5GcOaF14BcLp5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ac25c204ab79347fe59feaca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ac25c204ab79347fe59feaca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ac25c204ab79347fe59feaca',
#        'width': 64}],
#      'name': 'O2: Oxygen',
#      'release_date': '2019-09-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6gxgpYoqW5GcOaF14BcLp5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HTnM2pBGio6w5JhaUmb4o'},
#       'href': 'https://api.spotify.com/v1/artists/5HTnM2pBGio6w5JhaUmb4o',
#       'id': '5HTnM2pBGio6w5JhaUmb4o',
#       'name': 'NAME SIX',
#       'type': 'artist',
#       'uri': 'spotify:artist:5HTnM2pBGio6w5JhaUmb4o'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 167710,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCAEK1940246'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1unvnTGxx7B2mWIqpDdKnU'},
#     'href': 'https://api.spotify.com/v1/tracks/1unvnTGxx7B2mWIqpDdKnU',
#     'id': '1unvnTGxx7B2mWIqpDdKnU',
#     'is_local': False,
#     'name': 'Going Bad',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a17f61888237cad956be15d8a0cef346c14936af?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1unvnTGxx7B2mWIqpDdKnU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AqIRTZF6DDmKmdorgFug6'},
#        'href': 'https://api.spotify.com/v1/artists/4AqIRTZF6DDmKmdorgFug6',
#        'id': '4AqIRTZF6DDmKmdorgFug6',
#        'name': 'The Vandals',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AqIRTZF6DDmKmdorgFug6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1VDzkX1kHYOhlnHWQjqy05'},
#      'href': 'https://api.spotify.com/v1/albums/1VDzkX1kHYOhlnHWQjqy05',
#      'id': '1VDzkX1kHYOhlnHWQjqy05',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273474fdcf0e246e8e464a54b90',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02474fdcf0e246e8e464a54b90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851474fdcf0e246e8e464a54b90',
#        'width': 64}],
#      'name': 'Hitler Bad, Vandals Good',
#      'release_date': '1998-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1VDzkX1kHYOhlnHWQjqy05'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AqIRTZF6DDmKmdorgFug6'},
#       'href': 'https://api.spotify.com/v1/artists/4AqIRTZF6DDmKmdorgFug6',
#       'id': '4AqIRTZF6DDmKmdorgFug6',
#       'name': 'The Vandals',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AqIRTZF6DDmKmdorgFug6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 134933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNRR0400196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6AvpoXv2KL0rGYIcZ3v3QI'},
#     'href': 'https://api.spotify.com/v1/tracks/6AvpoXv2KL0rGYIcZ3v3QI',
#     'id': '6AvpoXv2KL0rGYIcZ3v3QI',
#     'is_local': False,
#     'name': 'People That Are Going To Hell',
#     'popularity': 34,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6AvpoXv2KL0rGYIcZ3v3QI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#        'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#        'id': '4TMHGUX5WI7OOm53PqSDAT',
#        'name': 'Grateful Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1iZbyAj4kT1U8lXtu4t415'},
#      'href': 'https://api.spotify.com/v1/albums/1iZbyAj4kT1U8lXtu4t415',
#      'id': '1iZbyAj4kT1U8lXtu4t415',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c1c53ee367fbacd25faf1dd8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c1c53ee367fbacd25faf1dd8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c1c53ee367fbacd25faf1dd8',
#        'width': 64}],
#      'name': 'Hundred Year Hall (Live)',
#      'release_date': '1995-09-26',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1iZbyAj4kT1U8lXtu4t415'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#       'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#       'id': '4TMHGUX5WI7OOm53PqSDAT',
#       'name': 'Grateful Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 452426,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH10900675'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3McI42RdYASgS0jigyagId'},
#     'href': 'https://api.spotify.com/v1/tracks/3McI42RdYASgS0jigyagId',
#     'id': '3McI42RdYASgS0jigyagId',
#     'is_local': False,
#     'name': "Goin' down the Road Feeling Bad - Live at Jahrhundert Halle, Frankfurt, Germany, April 26, 1972",
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d8cd1bc991d9edd828c7cffc52580db42e7a2fd?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3McI42RdYASgS0jigyagId'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eTZGzLkukATM7FoGltyFs'},
#        'href': 'https://api.spotify.com/v1/artists/1eTZGzLkukATM7FoGltyFs',
#        'id': '1eTZGzLkukATM7FoGltyFs',
#        'name': 'Elizabeth Cotten',
#        'type': 'artist',
#        'uri': 'spotify:artist:1eTZGzLkukATM7FoGltyFs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
# ...
#        'width': 64}],
#      'name': 'Solo Recordings, Vol. 3',
#      'release_date': '2016-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7s0ssvbmHNrMUA1z2TTp5k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2f1hLQKsXGmF9rxdrq6Jt4'},
#       'href': 'https://api.spotify.com/v1/artists/2f1hLQKsXGmF9rxdrq6Jt4',
#       'id': '2f1hLQKsXGmF9rxdrq6Jt4',
#       'name': 'Steve Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:2f1hLQKsXGmF9rxdrq6Jt4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 297880,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAO371684411'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GKIy4nMb4mclMsgsSoAsw'},
#     'href': 'https://api.spotify.com/v1/tracks/0GKIy4nMb4mclMsgsSoAsw',
#     'id': '0GKIy4nMb4mclMsgsSoAsw',
#     'is_local': False,
#     'name': 'Going Down the Road Feeling Bad',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7e1308b7351db87996923906f5bbffca03d4a6ed?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0GKIy4nMb4mclMsgsSoAsw'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19aZxgHJEtveuVPhDFTMMG'},
#      'href': 'https://api.spotify.com/v1/albums/19aZxgHJEtveuVPhDFTMMG',
#      'id': '19aZxgHJEtveuVPhDFTMMG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731df095837ba73ad5d6fa274d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021df095837ba73ad5d6fa274d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511df095837ba73ad5d6fa274d',
#        'width': 64}],
#      'name': 'Day of the Dead',
#      'release_date': '2016-05-20',
#      'release_date_precision': 'day',
#      'total_tracks': 59,
#      'type': 'album',
#      'uri': 'spotify:album:19aZxgHJEtveuVPhDFTMMG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/60ht0hWRy1yjUDfNsLuHuP'},
#       'href': 'https://api.spotify.com/v1/artists/60ht0hWRy1yjUDfNsLuHuP',
#       'id': '60ht0hWRy1yjUDfNsLuHuP',
#       'name': 'Lucinda Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:60ht0hWRy1yjUDfNsLuHuP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 244592,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL1600044'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2iRzk2IkDB25PXYskqPu8M'},
#     'href': 'https://api.spotify.com/v1/tracks/2iRzk2IkDB25PXYskqPu8M',
#     'id': '2iRzk2IkDB25PXYskqPu8M',
#     'is_local': False,
#     'name': "Goin' Down The Road Feeling Bad",
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7bb13fe06ec4712fcabd2704f8208117e024c5f6?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:2iRzk2IkDB25PXYskqPu8M'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/398uOjIcboA7cfnsTjn2yw'},
#        'href': 'https://api.spotify.com/v1/artists/398uOjIcboA7cfnsTjn2yw',
#        'id': '398uOjIcboA7cfnsTjn2yw',
#        'name': 'Bloody Jay',
#        'type': 'artist',
#        'uri': 'spotify:artist:398uOjIcboA7cfnsTjn2yw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lGfiKp8ZWMu6ITw3qh3Zi'},
#      'href': 'https://api.spotify.com/v1/albums/3lGfiKp8ZWMu6ITw3qh3Zi',
#      'id': '3lGfiKp8ZWMu6ITw3qh3Zi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c52731202ea812c250ce50b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c52731202ea812c250ce50b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c52731202ea812c250ce50b9',
#        'width': 64}],
#      'name': 'Real Forever',
#      'release_date': '2019-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3lGfiKp8ZWMu6ITw3qh3Zi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/398uOjIcboA7cfnsTjn2yw'},
#       'href': 'https://api.spotify.com/v1/artists/398uOjIcboA7cfnsTjn2yw',
#       'id': '398uOjIcboA7cfnsTjn2yw',
#       'name': 'Bloody Jay',
#       'type': 'artist',
#       'uri': 'spotify:artist:398uOjIcboA7cfnsTjn2yw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Berubt6ysOy2LCMyqhmXP'},
#       'href': 'https://api.spotify.com/v1/artists/5Berubt6ysOy2LCMyqhmXP',
#       'id': '5Berubt6ysOy2LCMyqhmXP',
#       'name': 'YFN Lucci',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Berubt6ysOy2LCMyqhmXP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#       'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#       'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#       'name': 'Boosie Badazz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 263079,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM7TQ1900013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ffUbnOFjP4sb9kGCNHFj0'},
#     'href': 'https://api.spotify.com/v1/tracks/6ffUbnOFjP4sb9kGCNHFj0',
#     'id': '6ffUbnOFjP4sb9kGCNHFj0',
#     'is_local': False,
#     'name': 'Keep Going (feat. YFN Lucci & Boosie Bad Azz)',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b75c9eb7a6946cd306d323dcb9a102ad477b2e09?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6ffUbnOFjP4sb9kGCNHFj0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uNcfNhlVJUyEX0t0NG1m1'},
#        'href': 'https://api.spotify.com/v1/artists/2uNcfNhlVJUyEX0t0NG1m1',
#        'id': '2uNcfNhlVJUyEX0t0NG1m1',
#        'name': 'Eric Bibb',
#        'type': 'artist',
#        'uri': 'spotify:artist:2uNcfNhlVJUyEX0t0NG1m1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/28hU6a2lwgMYwxNjsYYmn7'},
#      'href': 'https://api.spotify.com/v1/albums/28hU6a2lwgMYwxNjsYYmn7',
#      'id': '28hU6a2lwgMYwxNjsYYmn7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d4a135b0dd4a83229e24b66',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d4a135b0dd4a83229e24b66',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d4a135b0dd4a83229e24b66',
#        'width': 64}],
#      'name': 'Blues, Ballads & Work Songs',
#      'release_date': '2011-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:28hU6a2lwgMYwxNjsYYmn7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uNcfNhlVJUyEX0t0NG1m1'},
#       'href': 'https://api.spotify.com/v1/artists/2uNcfNhlVJUyEX0t0NG1m1',
#       'id': '2uNcfNhlVJUyEX0t0NG1m1',
#       'name': 'Eric Bibb',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uNcfNhlVJUyEX0t0NG1m1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 187440,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEYOK1639489'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/22vUpe2F8ShNsJK89sg53f'},
#     'href': 'https://api.spotify.com/v1/tracks/22vUpe2F8ShNsJK89sg53f',
#     'id': '22vUpe2F8ShNsJK89sg53f',
#     'is_local': False,
#     'name': 'Goin Down That Road Feelin´ Bad',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ba7f82523fb1702ba21e6248deeebffffa1af211?cid=01bc58e4e76d429f8bed442781557932',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:22vUpe2F8ShNsJK89sg53f'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3Agoin+bad&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 845}}

# %%
# spotify.get_artist("20sxb77xiYeusSH8cVdatc")

# %%
# headers = {
#     "authorization":f"Bearer {access_token}"
# }

# endpoint = "https://api.spotify.com/v1/search"
# data = urlencode({"q":"time", "type": "track"})

# lookup_url = f"{endpoint}?{data}"
# r = requests.get(lookup_url, headers=headers)

# %%
# r.json()
